# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
df = pd.read_csv('Feo_analysis_data.csv')
df.set_index('Date',drop=True, inplace=True)

# %%
df.head()
# Out:
#             Blane_before_hpgr  Blane_after_hpgr       MC%      Drop  \
# Date
# 2019-03-22        1664.166667       1944.333333  9.068056  4.198194
# 2019-03-23        1664.307692       2014.000000  8.997183  4.894366
# 2019-03-24        1640.000000       2036.909091  8.795833  4.649583
# 2019-03-26        1640.090909       2034.181818  9.001493  5.343582
# 2019-03-28        1593.916667       1998.500000  8.850000  4.608088
#
#             710FN3_Damper(%)  Water_Mix1(m3-h)  Water_Mix2(m3-h)  \
# Date
# 2019-03-22             34.56              3.77              2.85
# 2019-03-23             34.01              5.68              2.77
# 2019-03-24             28.01              5.07              3.07
# 2019-03-26             34.39              4.49              4.48
# 2019-03-28             38.36              3.44              3.23
#
#             Water_Mixer_Total  Killn_Speed(rpm)  TG_Zone1_Temp(deg)  ...  \
# Date                                                                 ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 646 entries, 2019-03-22 to 2022-02-12
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Blane_before_hpgr   646 non-null    float64
#  1   Blane_after_hpgr    646 non-null    float64
#  2   MC%                 646 non-null    float64
#  3   Drop                646 non-null    float64
#  4   710FN3_Damper(%)    646 non-null    float64
#  5   Water_Mix1(m3-h)    646 non-null    float64
#  6   Water_Mix2(m3-h)    646 non-null    float64
#  7   Water_Mixer_Total   646 non-null    float64
#  8   Killn_Speed(rpm)    646 non-null    float64
#  9   TG_Zone1_Temp(deg)  646 non-null    float64
#  10  710FN1_Damper(%)    646 non-null    float64
#  11  730FN1_Damper(%)    646 non-null    float64
#  12  Grate_Feed(ton)     646 non-null    float64
#  13  OffGas(deg)         646 non-null    float64
#  14  WF5(t-h)            646 non-null    float64
# ...

# %%
plt.figure(figsize=(11,7),dpi=80)
plt.title('Grate Speed (rpm)', fontsize=20,fontweight='bold')
f=sns.lineplot(x='Date', y=df['Grate_Speed(rpm)'], data=df,)
f.set_xlabel("Date", fontsize = 18)
f.set_ylabel('Grate Speed', fontsize = 18)
f.set_xticks([1,200,400,550,645])
plt.show()

# %%
data = df['Pellet_Feo'].value_counts()
data
# Out:
# Good         286
# Not Bad      270
# Bad           75
# Very Good     15
# Name: Pellet_Feo, dtype: int64

# %%
plt.figure(figsize=(11,7))
plt.text(1,1,'Feo < 0.5%                ==> Very Good')
plt.text(1,1.1,'0.5% < Feo < 0.8%   ==> Good')
plt.text(1,1.2,'0.8% < Feo < 1.2%   ==> Not Bad')
plt.text(1,1.3,'Feo > 1.2%                ==> Bad')
data.plot.pie(autopct = '%0.0f%%', textprops={'fontsize': 18})
# Out:
# <AxesSubplot:ylabel='Pellet_Feo'>

# %%
sns.displot(
    data=df,
    x="TG_Zone1_Temp(deg)",
    hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=7,
    fill=True,
    alpha = 0.05,
)
plt.xlim(190,260)
plt.xticks([210,236,224])
plt.axvline(236, c='green')
plt.axvline(224, c='green')
plt.axvline(210, c='red')

# %%
sns.displot(
    data=df,
    x="Grate_Feed(ton)", hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=6,
    fill=True,
    alpha = 0.1,
)
plt.xlim(11700,14300)
plt.xticks([12710,12965],rotation=45)
plt.axvline(12965, c='green')
plt.axvline(12710, c='red')

# %%
sns.displot(
    data=df,
    x="Wf5&6_total", hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=6,
    fill=True,
    alpha = 0.1,
)
plt.xlim(10,60)
plt.xticks([35,41],rotation=45)
plt.axvline(35, c='green')
plt.axvline(41, c='red')

# %%
sns.displot(
    data=df,
    x="Water_Mixer_Total", hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=6,
    fill=True,
    alpha = 0.1,
)
plt.xlim(0,12.5)
plt.xticks([6.1,8.7],rotation=45)
plt.axvline(8.7, c='green')
plt.axvline(6.1, c='red')

# %%
sns.displot(
    data=df,
    x="Drop", hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=6,
    fill=True,
    alpha = 0.1,
)
plt.xlim(3,6)
plt.xticks([3.9,4.2,4.6],rotation=45)
plt.axvline(3.9, c='green')
plt.axvline(4.2, c='green')
plt.axvline(4.6, c='red')

# %%
sns.displot(
    data=df,
    x="OffGas(deg)", hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=6,
    fill=True,
    alpha = 0.1,
)
plt.xlim(750,1000)
plt.xticks([805,860,915],rotation=45)
plt.axvline(860, c='green')
plt.axvline(915, c='green')
plt.axvline(805, c='red')

# %%
sns.displot(
    data=df,
    x="730FN1_Damper(%)",
    hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=7,
    fill=True,
    alpha = 0.05,
)
plt.xlim(30,55)
plt.xticks([36.4,36.9,47.8],rotation=90)
plt.axvline(36.4, c='green')
plt.axvline(47.8, c='green')
plt.axvline(36.9, c='red')

# %%
sns.displot(
    data=df,
    x="710FN1_Damper(%)",
    hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=7,
    fill=True,
    alpha = 0.05,
)
plt.xlim(35,70)
plt.xticks([50.5,56.5])
plt.axvline(50.5, c='green')
plt.axvline(56.5, c='red')

# %%
sns.displot(
    data=df,
    x="710FN3_Damper(%)", hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=6,
    fill=True,
    alpha = 0.1,
)
plt.xlim(30,55)
plt.xticks([36,44.5,46.1],rotation=90)
plt.axvline(46.1, c='green')
plt.axvline(36, c='green')
plt.axvline(44.5, c='red')

# %%
sns.displot(
    data=df,
    x="Grate_Speed(rpm)", hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=6,
    fill=True,
    alpha = 0.1,
)
plt.xlim(5.2,7)
plt.xticks([5.8,6.07],rotation=45)
plt.axvline(5.8, c='green')
plt.axvline(6.07, c='red')

# %%
sns.displot(
    data=df,
    x="Killn_Speed(rpm)", hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=6,
    fill=True,
    alpha = 0.1,
)
plt.xlim(1.4,1.8)
plt.xticks([1.536,1.675,1.69],rotation=45)
plt.axvline(1.536, c='green')
plt.axvline(1.675, c='green')
plt.axvline(1.69, c='red')

# %%
sns.displot(
    data=df,
    x="Blane_after_hpgr", hue="Pellet_Feo",
    hue_order=['Very Good','Good','Not Bad','Bad'],
    kind="kde", height=6,
    fill=True,
    alpha = 0.1,
)
plt.xticks([1870,1950],rotation=45)

plt.axvline(1870, c='red')
plt.axvline(1950, c='blue')
#plt.axvline(56, c='green')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2492/2095800286.py in <module>
# ----> 1 a,b=plt.subplot()
#
# TypeError: cannot unpack non-iterable AxesSubplot object
